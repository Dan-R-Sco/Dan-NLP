# %%
import tweepy
import datetime

#etract rstats from twitter between dates
searchedTag = "rstats"

#for tweet in tweepy.Cursor(api.search, q= searchedTag, since='2014-09-16', until='2014-10-17').items(5):
for tweet in tweepy.Cursor(api.search, q=('"Trump"'), start='2014-09-16', end='2014-09-17').items(5):
    print("Name:", tweet.author.name.encode('utf8'))
    print("Screen-name:", tweet.author.screen_name.encode('utf8'))
    print("Tweet created:", tweet.created_at)
    print("Tweet:", tweet.text.encode('utf8'))
    print("Retweeted:", tweet.retweeted)
    print("Favourited:", tweet.favorited)
    print("Location:", tweet.user.location.encode('utf8'))
    print("Time-zone:", tweet.user.time_zone)
    print("Geo:", tweet.geo)
    print("//////////////////")
# Out:
# Name: b'Rebel Yell \xf0\x9f\x8c\x8a'
# Screen-name: b'dninci'
# Tweet created: 2020-05-29 01:50:53
# Tweet: b'RT @SassyKadiK: I\xe2\x80\x99m still trying to figure out exactly what Trump\xe2\x80\x99s executive order addressing social media accomplished other than to make\xe2\x80\xa6'
# Retweeted: False
# Favourited: False
# Location: b'Texas, USA'
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'regina terry'
# Screen-name: b'ginap4462'
# Tweet created: 2020-05-29 01:50:53
# Tweet: b'RT @ccunningham821: @NoodleSparklez @inthecopa Trump called it a hoax from the start-he must have known'
# Retweeted: False
# Favourited: False
# Location: b''
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'Zayza Tree'
# Screen-name: b'ZayzaTree'
# Tweet created: 2020-05-29 01:50:53
# Tweet: b'RT @RKJ65: The State Department is gutted &amp; useless.\n\nThe CDC is dysfunctional during a deadly pandemic.\n\nThe Justice Department has been t\xe2\x80\xa6'
# Retweeted: False
# Favourited: False
# Location: b'Vestal Tennessee'
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'\xf0\x9f\x85\x9b\xf0\x9f\x85\xa4\xf0\x9f\x85\xa9'
# Screen-name: b'Luz_Bergese'
# Tweet created: 2020-05-29 01:50:53
# Tweet: b'Trump te amo'
# Retweeted: False
# Favourited: False
# Location: b''
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'Maggie Harper'
# Screen-name: b'painterly111'
# Tweet created: 2020-05-29 01:50:53
# Tweet: b'RT @Pappiness: @realDonaldTrump Trump knows that his power has always been based on spreading misinformation on social media. By him, by hi\xe2\x80\xa6'
# Retweeted: False
# Favourited: False
# Location: b'Philadelphia, PA USA'
# Time-zone: None
# Geo: None
# //////////////////

# %% [markdown]
# # put data into DF

# %%
import pandas as pd

query = 'python'
max_tweets = 100

#tweets = self.get_tweets(query = 'Ethereum', count=1000, page = 1, start=datetime.date.today()-datetime.timedelta(days=30), end=datetime.date.today())
searched_tweets = [status for status in tweepy.Cursor(api.search, q=query, START='2015-01-01', END='2016-01-01').items(max_tweets)]
json_data = [r._json for r in searched_tweets]
df = pd.io.json.json_normalize(json_data)
len(df)
# Out:
# /home/dan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
# 100

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Fri May 29 01:53:11 +0000 2020  1266185791266570240  1266185791266570240
# 1  Fri May 29 01:53:09 +0000 2020  1266185779715338242  1266185779715338242
# 2  Fri May 29 01:53:05 +0000 2020  1266185764854996992  1266185764854996992
# 3  Fri May 29 01:53:02 +0000 2020  1266185750778834944  1266185750778834944
# 4  Fri May 29 01:52:59 +0000 2020  1266185739508875264  1266185739508875264
#
#                                                 text  truncated  \
# 0  RT @_marcba: If you like Python, code Python.\...      False
# 1  Using the Python context manager for declaring...      False
# 2  RT @gp_pulipaka: #MachineLearning: Colab- Why,...      False
# 3         Pythonのcollections.dequeって高速にリストに変換できるのかな？      False
# 4  RT @TerranigmArk: En la próxima sesión de Pyth...      False
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 2  <a href="http://twitter.com/download/android" ...                    NaN
# 3  <a href="https://about.twitter.com/products/tw...                    NaN
# 4  <a href="http://twitter.com/download/android" ...                    NaN
#
#   in_reply_to_status_id_str  in_reply_to_user_id in_reply_to_user_id_str  ...  \
# 0                      None                  NaN                    None  ...
# 1                      None                  NaN                    None  ...
# 2                      None                  NaN                    None  ...
# 3                      None                  NaN                    None  ...
# 4                      None                  NaN                    None  ...
#
#   place.id place.url place.place_type  place.name place.full_name  \
# 0      NaN       NaN              NaN         NaN             NaN
# 1      NaN       NaN              NaN         NaN             NaN
# 2      NaN       NaN              NaN         NaN             NaN
# 3      NaN       NaN              NaN         NaN             NaN
# 4      NaN       NaN              NaN         NaN             NaN
#
#    place.country_code  place.country  place.contained_within  \
# 0                 NaN            NaN                     NaN
# 1                 NaN            NaN                     NaN
# 2                 NaN            NaN                     NaN
# 3                 NaN            NaN                     NaN
# 4                 NaN            NaN                     NaN
#
#    place.bounding_box.type  place.bounding_box.coordinates
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
#
# [5 rows x 241 columns]

# %% [markdown]
# # write to xls

# %%
import xlsxwriter
import sys

workbook = 'out.csv'

df.to_csv(workbook, index=False) 

print("Excel file ready")
# Out:
# Excel file ready
