# %%
#download all tweets relating to A hashtag

# %%
import csv
import pandas as pd
from tweepy import OAuthHandler
from tweepy import API

#authentication
consumer_key = 'OoKNiUsHi0GIXY8K312L2JgfD' #api key
consumer_secret = '9uSfIR3R6O0oCqRRNGi9ZNBVLk0j8BP3wvM2F4qyiXR97fvYNv' #api password
access_token= '213080756-Co7ZfxlNdFYrfySJzhWxh6VFY8CnooQds31VNJz5' 
access_token_secret= 'YMVvPOkaViHHvDVYsod8nQUn1zJOwSmN9wukcTKP40W88'

auth = OAuthHandler(consumer_key, consumer_secret)

auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)

# %%
results = api.search(q='rstats', count=100)

# %%
json_data = [r._json for r in results]

# %%
df = pd.io.json.json_normalize(json_data)
# Out:
# /home/dan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.

# %%
df.head(25)
# Out:
#                         created_at                   id               id_str  \
# 0   Thu May 28 22:07:20 +0000 2020  1266128954232012800  1266128954232012800
# 1   Thu May 28 22:06:13 +0000 2020  1266128670609022983  1266128670609022983
# 2   Thu May 28 22:05:43 +0000 2020  1266128543722795008  1266128543722795008
# 3   Thu May 28 22:04:51 +0000 2020  1266128328324534273  1266128328324534273
# 4   Thu May 28 22:04:09 +0000 2020  1266128152054677506  1266128152054677506
# 5   Thu May 28 22:04:05 +0000 2020  1266128135512301570  1266128135512301570
# 6   Thu May 28 22:04:04 +0000 2020  1266128132538425344  1266128132538425344
# 7   Thu May 28 22:04:04 +0000 2020  1266128128453292034  1266128128453292034
# 8   Thu May 28 22:03:49 +0000 2020  1266128069267533824  1266128069267533824
# 9   Thu May 28 22:02:08 +0000 2020  1266127645676318720  1266127645676318720
# 10  Thu May 28 22:01:59 +0000 2020  1266127607801671681  1266127607801671681
# ...

# %%
df['text'][1]
# Out:
# 'Indiana COVID-19 Tracker evening update. More charts and analysis at\nhttps://t.co/FOgsGZj84J #rstats https://t.co/4ShLbMkFOS'

# %%
import tweepy

csvFile = open('ua.csv','a')
#use csv writer
csvWriter = csv.writer(csvFile)

searchedTag = "unitedAirlines"
sinceDate = '2017-04-03'
#since='2015-03-16', until='2015-03-17'


#limits 200 
for tweet in tweepy.Cursor(api.search, q= searchedTag, start='2015-03-16', end='2020-03-20',count = 100, lang = 'en').items(200):
    print(status.user.name),
    print(status.user.screen_name),
    print("--- "),
    print(status.user.location),
    print("--- "),
    print(status.text),
    print(status.coordinates),
    print(status.source)
    print("")
    csvWriter.writerow([tweet.created_at, tweet.text.encode('utf-8')])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-1d1fbfd0ab23> in <module>
# ----> 1 class SListener(StreamListener):
#       2     def on_status(self, status):
#       3         print(status.text)
#       4     def on_error(self, status_code):
#       5         if status_code == 420:
#
# NameError: name 'StreamListener' is not defined

# %%
searchedTag = "rstats"

#for tweet in tweepy.Cursor(api.search, q= searchedTag, since='2014-09-16', until='2014-10-17').items(5):
for tweet in tweepy.Cursor(api.search, q=('"good book"'), since='2014-09-16', until='2014-09-17').items(5):
    print("Name:", tweet.author.name.encode('utf8'))
    print("Screen-name:", tweet.author.screen_name.encode('utf8'))
    print("Tweet created:", tweet.created_at)
    print("Tweet:", tweet.text.encode('utf8'))
    print("Retweeted:", tweet.retweeted)
    print("Favourited:", tweet.favorited)
    print("Location:", tweet.user.location.encode('utf8'))
    print("Time-zone:", tweet.user.time_zone)
    print("Geo:", tweet.geo)
    print("//////////////////")

# %%
look at this for next step:
    https://stackoverflow.com/questions/47925828/how-to-create-a-pandas-dataframe-using-tweepy
