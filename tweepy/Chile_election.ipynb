# %%
import tweepy
import datetime

#etract rstats from twitter between dates
searchedTag = ['#Piñera']

#for tweet in tweepy.Cursor(api.search, q= searchedTag, since='2014-09-16', until='2014-10-17').items(5):
for tweet in tweepy.Cursor(api.search, q=searchedTag, lang="es").items(5):
    print("Name:", tweet.author.name.encode('utf8'))
    print("Screen-name:", tweet.author.screen_name.encode('utf8'))
    print("Tweet created:", tweet.created_at)
    print("Tweet:", tweet.text.encode('utf8'))
    print("Retweeted:", tweet.retweeted)
    print("Favourited:", tweet.favorited)
    print("Location:", tweet.user.location.encode('utf8'))
    print("Time-zone:", tweet.user.time_zone)
    print("Geo:", tweet.geo)
    print("//////////////////")
# Out:
# Name: b'Niluf@cks\xe2\x99\x94 #Apruebo'
# Screen-name: b'monitared'
# Tweet created: 2020-05-29 02:01:22
# Tweet: b'RT @miryamce: @JoseRepenning Ay ni\xc3\xb1o qu\xc3\xa9 chanta t\xc3\xba. Pidiendo "unidad" luego de actuar c prepotencia y displicencia. Sinti\xc3\xa9ndote seguro en t\xe2\x80\xa6'
# Retweeted: False
# Favourited: False
# Location: b''
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'Patricio Castillo Ll'
# Screen-name: b'DHENOC'
# Tweet created: 2020-05-29 01:59:02
# Tweet: b'Lejos estoy de defender a #Ma\xc3\xb1alich, pero lo que dijo acerca de desconocer la mala calidad social y econ\xc3\xb3mica que v\xe2\x80\xa6 https://t.co/nbH9XNUgt1'
# Retweeted: False
# Favourited: False
# Location: b'Concepci\xc3\xb3n, Chile'
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'Jos\xc3\xa9 Luis'
# Screen-name: b'JoosChile'
# Tweet created: 2020-05-29 01:51:07
# Tweet: b'Las pol\xc3\xadticos sin distinci\xc3\xb3n en vez de multar y criticar el actuar de la gente deberian fijarse que si se trabaja p\xe2\x80\xa6 https://t.co/XoqsRa6Ly6'
# Retweeted: False
# Favourited: False
# Location: b'Chile'
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'@Coprosma'
# Screen-name: b'EzequielAlday'
# Tweet created: 2020-05-29 01:48:22
# Tweet: b'RT @NoMsDuopolioCh1: Veo a #pi\xc3\xb1era lamentablemente el #presidente de #Chile por cadena nacional un espect\xc3\xa1\xc3\xb1aculo patetico ahora habla de un\xe2\x80\xa6'
# Retweeted: False
# Favourited: False
# Location: b'Valpara\xc3\xadso'
# Time-zone: None
# Geo: None
# //////////////////
# Name: b'Gonzalo Villagra '
# Screen-name: b'GVillagraJ'
# Tweet created: 2020-05-29 01:45:54
# Tweet: b'#desarollosocial #minsal #elbosquedesperto #elbosque @SadiMelo #LaPintana #sanbernardo #cerronavia @TVN\xe2\x80\xa6 https://t.co/SLsuV2TPOE'
# Retweeted: False
# Favourited: False
# Location: b''
# Time-zone: None
# Geo: None
# //////////////////

# %% [markdown]
# # put data into DF

# %%
import pandas as pd

max_tweets = 1000

#tweets = self.get_tweets(query = 'Ethereum', count=1000, page = 1, start=datetime.date.today()-datetime.timedelta(days=30), end=datetime.date.today())
searched_tweets = [status for status in tweepy.Cursor(api.search, q=searchedTag, START='2015-01-01', END='2016-01-01').items(max_tweets)]
json_data = [r._json for r in searched_tweets]
df = pd.io.json.json_normalize(json_data)
len(df)
# Out:
# /home/dan/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# 1000

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Fri May 29 02:13:01 +0000 2020  1266190782677032961  1266190782677032961
# 1  Fri May 29 02:13:00 +0000 2020  1266190775077031937  1266190775077031937
# 2  Fri May 29 02:12:28 +0000 2020  1266190640934785024  1266190640934785024
# 3  Fri May 29 02:11:08 +0000 2020  1266190307978358786  1266190307978358786
# 4  Fri May 29 02:01:22 +0000 2020  1266187848224509957  1266187848224509957
#
#                                                 text  truncated  \
# 0  Logica de #Piñera y #Carabineros...0 fiscaliza...       True
# 1  RT @Payazo_krozty: Si #Mañalich "no tenía conc...      False
# 2  Si #Mañalich "no tenía conciencia" del hacinam...       True
# 3  Si el Gob de #Piñera, los partidos, privados y...       True
# 4  RT @miryamce: @JoseRepenning Ay niño qué chant...      False
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="http://twitter.com/download/android" ...                    NaN
# 2  <a href="http://twitter.com/download/android" ...                    NaN
# 3  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 4  <a href="http://twitter.com/download/android" ...                    NaN
#
#   in_reply_to_status_id_str  in_reply_to_user_id in_reply_to_user_id_str  ...  \
# 0                      None                  NaN                    None  ...
# 1                      None                  NaN                    None  ...
# 2                      None                  NaN                    None  ...
# 3                      None                  NaN                    None  ...
# 4                      None                  NaN                    None  ...
#
#   quoted_status.place.country  quoted_status.place.contained_within  \
# 0                         NaN                                   NaN
# 1                         NaN                                   NaN
# 2                         NaN                                   NaN
# 3                         NaN                                   NaN
# 4                         NaN                                   NaN
#
#    quoted_status.place.bounding_box.type  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    quoted_status.place.bounding_box.coordinates geo.type  geo.coordinates  \
# 0                                           NaN      NaN              NaN
# 1                                           NaN      NaN              NaN
# 2                                           NaN      NaN              NaN
# 3                                           NaN      NaN              NaN
# 4                                           NaN      NaN              NaN
#
#    coordinates.type  coordinates.coordinates  \
# 0               NaN                      NaN
# 1               NaN                      NaN
# 2               NaN                      NaN
# 3               NaN                      NaN
# 4               NaN                      NaN
#
#    retweeted_status.quoted_status.entities.media  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    retweeted_status.quoted_status.extended_entities.media
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 332 columns]

# %% [markdown]
# # write to csv

# %%
import xlsxwriter
import sys

workbook = 'out.csv'

df.to_csv(workbook, index=False) 

print("Excel file ready")
# Out:
# Excel file ready

# %% [markdown]
# ## Sentiment

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from textblob import TextBlob

#init sentiment
sid = SentimentIntensityAnalyzer

#score tweets
df['sentiment'] = df.text.apply(lambda x: TextBlob(str(x)).sentiment.polarity)

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Fri May 29 02:13:01 +0000 2020  1266190782677032961  1266190782677032961
# 1  Fri May 29 02:13:00 +0000 2020  1266190775077031937  1266190775077031937
# 2  Fri May 29 02:12:28 +0000 2020  1266190640934785024  1266190640934785024
# 3  Fri May 29 02:11:08 +0000 2020  1266190307978358786  1266190307978358786
# 4  Fri May 29 02:01:22 +0000 2020  1266187848224509957  1266187848224509957
#
#                                                 text  truncated  \
# 0  Logica de #Piñera y #Carabineros...0 fiscaliza...       True
# 1  RT @Payazo_krozty: Si #Mañalich "no tenía conc...      False
# 2  Si #Mañalich "no tenía conciencia" del hacinam...       True
# 3  Si el Gob de #Piñera, los partidos, privados y...       True
# 4  RT @miryamce: @JoseRepenning Ay niño qué chant...      False
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 1  <a href="http://twitter.com/download/android" ...                    NaN
# 2  <a href="http://twitter.com/download/android" ...                    NaN
# 3  <a href="https://mobile.twitter.com" rel="nofo...                    NaN
# 4  <a href="http://twitter.com/download/android" ...                    NaN
#
#   in_reply_to_status_id_str  in_reply_to_user_id in_reply_to_user_id_str  ...  \
# 0                      None                  NaN                    None  ...
# 1                      None                  NaN                    None  ...
# 2                      None                  NaN                    None  ...
# 3                      None                  NaN                    None  ...
# 4                      None                  NaN                    None  ...
#
#   quoted_status.place.contained_within  quoted_status.place.bounding_box.type  \
# 0                                  NaN                                    NaN
# 1                                  NaN                                    NaN
# 2                                  NaN                                    NaN
# 3                                  NaN                                    NaN
# 4                                  NaN                                    NaN
#
#    quoted_status.place.bounding_box.coordinates  geo.type geo.coordinates  \
# 0                                           NaN       NaN             NaN
# 1                                           NaN       NaN             NaN
# 2                                           NaN       NaN             NaN
# 3                                           NaN       NaN             NaN
# 4                                           NaN       NaN             NaN
#
#    coordinates.type  coordinates.coordinates  \
# 0               NaN                      NaN
# 1               NaN                      NaN
# 2               NaN                      NaN
# 3               NaN                      NaN
# 4               NaN                      NaN
#
#    retweeted_status.quoted_status.entities.media  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    retweeted_status.quoted_status.extended_entities.media  sentiment
# 0                                                NaN             0.0
# 1                                                NaN             0.0
# 2                                                NaN             0.0
# 3                                                NaN             0.0
# 4                                                NaN             0.0
#
# [5 rows x 333 columns]

# %%
print(df['sentiment'].value_counts())

#
#print(df[df.sentiment > 0]['text'])
# Out:
#  0.000000    967
#  0.033333     13
#  0.268333      3
# -0.400000      3
#  0.050000      3
# -0.300000      2
#  0.100000      1
# -0.100000      1
#  0.600000      1
#  0.200000      1
#  0.050000      1
#  0.577500      1
#  0.500000      1
# -0.500000      1
# -1.000000      1
# Name: sentiment, dtype: int64

# %%
# Print out the text of a positive tweet
#print(df[df.sentiment > 0.6]['text'])

# Print out the text of a negative tweet
#print(df['sentiment' < -0.6]['text'].values[0])

# Generate average sentiment scores for #python
#sentiment_py = sentiment[ check_word_in_tweet(searchedTag, df) ].resample('1 d').mean()
# Out:
# 1     Lejos estoy de defender a #Mañalich, pero lo q...
# 74    RT @ElectsWorld: 🇨🇱#Chile, President #Piñera m...
# 99    RT @ddhh_1810: Ambulances in #Chile forced 2 w...
# Name: text, dtype: object

# %%
# Import matplotlib
import matplotlib.pyplot as plt

# Plot average #python sentiment per day
plt.plot(____, ____, color = 'green')

# Plot average #rstats sentiment per day
plt.plot(____, ____, color = 'blue')

plt.xlabel('Day')
plt.ylabel('Sentiment')
plt.title('Sentiment of data science languages')
plt.legend(('#python', '#rstats'))
plt.show()
